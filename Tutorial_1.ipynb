# %% [markdown]
# <h1><center><u><font color="red">Tutorial 1 </font></u> </center></h1>
#
# <h1><center><font color="blue">Newtonian Chirp - Time Domain Signal </font></center></h1>
#
# <p> Consider a system of two compact stars (Black Holes or Neutron stars) with masses mass1 and mass2 in a circular orbit. Such a system will lose energy by gravitational-wave (GW) emission and the stars will spiral inwards such that the orbital frequency increases with time following Kepler’s third law. The emitted gravitational waveform is a "chirp" with both amplitude and frequency increasing with
# time. When the stars are widely separated, the problem can
# be treated perturbatively. In the leading order post-Newtonian
# approximation, the observed GW signal, which is a linear
# combination of the two polarizations h + (t) and h × (t), can be
# computed as:<p>
#
# \begin{equation}
# h(t) = A(t) \; cos ( \phi (t))
# \end{equation}
#
# <u><font color="magenta"> Equation 1: Estimate Chirp Mass </font> </u>
#
# Reduced Mass
# \begin{equation}
# \mu = m1 * m2 / (m1 + m2)
# \end{equation}
#
# Chirp Mass
# \begin{equation}
# M  = \mu^{\frac{3}{5}} * (m1 + m2)^{\frac{2}{5}}
# \end{equation}
#
# <u> <font color="magenta">Equatoin 2: Estimate Coalescence time </font></u>
#
# \begin{equation}
# T_c = \frac{5}{256 (\pi F_o)^{8/3} M^{5/3}}
# \end{equation}
#
# <u> <font color="magenta">Equaton 3: Estimate Frequency Evolution F(t) </font></u>
#
# \begin{equation}
# F(t) = \frac{(M F_o^9)^{1/8)}}{[(M F_o)^{1/3} - (256 F_o^3 M^2 \pi^{8/3} t/5)]^{3/8}}
# \end{equation}
#
# <u> <font color="magenta">Equation 4: Estimate Amplitude A(t) </font></u>
#
# <p>
# The amplitude A(t) depends on a particular combination of the masses, called the chirp mass M, the instantaneous frequency F(t) of GWs, the luminosity distance D to the source, and a geometric factor C that depends on the location of the source in the sky and its orientation with respect to the detector. For simplicity, we shall assume <font color ="blue"> C = 1 </font> which implies that the binary is conveniently oriented giving circular polarization and the source is located along the direction where the detector shows maximum directional sensitivity.
# </p>
#
# \begin{equation}
# A(t) = C \Bigg( \frac{4M^{5/3} (\pi F(t))^{2/3}}{D} \Bigg)
# \end{equation}
#
#
# <u> <font color="magenta"> Equation 5: Phase of the GW signal </font></u>
#
# \begin{equation}
# \phi(t) = \phi_o - 2 \Bigg[\frac{1}{256 (\pi M F_o)^{8/3}} - \frac{t}{5M} \Bigg]^{5/8}
# \end{equation}
#
#
# <u><font color="magenta"> Equation 6: Time domain of Newtonian Chirp signal </font></u>
#
# \begin{equation}
# h(t) = A(t) \; cos ( \phi (t))
# \end{equation}
#
#
# <u> <font color="magenta">Notations </font></u>
#
#
# | Defination | Math Symbol | Python Variable |
# | --- | --- | --- |
# | Chirp Mass | $M$ | Chirp_mass |
# | Mass 1 | $m1$ | m1 |
# | Mass 2 | $m2$ | m2 |
# | Starting frequency of the Signal | $F_o$ | fnot |
# | Coalescence time | $ T_c$ | tc |
# | Time range | $t$ | time_range|
# | Frequency Evolution | $F(t)$ | freq_evol |
# | Distance | $ D $ | distance |
# | Amplitude | $ A(t) $ | amplitude |
# | Phase | $ \phi (t) $ | phase |
# | Time domain Newtonian chirp  | h(t) | td_nchirp |

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Global variables
global MSUN,  PC, PI, COS

# Solar Mass in seconds
# GM/C^3
MSUN = 4.925491025543575903411922162094833998e-6

# One Parsec in seconds
PC = 1.0292712503e8

# PI
PI = np.pi

# COS
COS = np.cos

# %%
def td_newtonian_chirp(m1, m2, fnot, phi_not, distance, time_range):
    """
    Compute time domain newtonian chirp h(t)

    Parameters
    ----------
    m1: float
        Mass of the compact object 1

    m2: float
        Mass of the compact object 2

    fnot: float
          Startig frequency of the Signal
          
    phi_not: float
             Phase at some time.

    distance: float
              Luminosity distance D to the source

    time_range: array-like
                Time array of the signal in sec

    Return
    ------
    td_nchirp: array-like
               Time domain Newtonian chirp h(t)

    idx: array-like
         Indices required for plotting

    """
    # ----------------------------------------------------------------------- #
    # ----------------------------------------------------------------------- #
    # ---- **** Edit your code here **** ----


    # Chirp Mass
    Chirp_mass = 

    # Coalescence time
    tc = 

    # ----------------------------------------------------------------------- #
    # ----------------------------------------------------------------------- #
    # Index of time range, where coalescence time is greater than the time range
    idx = time_range < tc 
    # Coalescence time duration
    tc_array = time_range[idx]
    # Initialize time domain Newtonian chirp array
    td_nchirp = np.zeros(len(time_range))
    # Duration of Coalescence time
    tc_duration = tc
    # Reassign the coalescence duration time into coalescence array
    tc = tc_array
    # ----------------------------------------------------------------------- #
    # ----------------------------------------------------------------------- #
    # ---- **** Edit your code here **** ----

    # Frequency evolution
    freq_evol = 

    # Amplitude
    amplitude = 

    # Phase
    phase = 

    # Time domain Newtonian chirp
    td_nchirp[idx] = 

    # ----------------------------------------------------------------------- #
    # ----------------------------------------------------------------------- #
    print("------------------------------------------------------------------")
    print(" Chirp Mass (Solar Mass sec)             :", Chirp_mass)
    print(" Coalescence time (sec)                  :", tc_duration)
    print(" Frequency evolution - First data point  :", freq_evol[0]) 
    print(" Amplitude - First data point            :", amplitude[0])
    print(" Phase - First data point                :", phase[0])
    print(" TD Newtonian chirp - First data point   :", td_nchirp[0])
    print("------------------------------------------------------------------")

    return td_nchirp, idx
# Out:
#   File "<ipython-input-7-2dc079f44ca4>", line 41
#     Chirp_mass =
#                  ^
# SyntaxError: invalid syntax

# %% [markdown]
# <u> <font color="green">Input parameters </font></u>
# Duration of signal = 16 s
#
# Mass of object 1 =  20 $M_\odot$
#
# Mass of object 2 = 10 $M_\odot$
#
# Distance = 100 MPc [ MPc = Mega Parsec, 1 Mega = $10^6$ ]
#
# Fnot = 30 Hz

# %%
# Duration of the signal
tduration = 16

# create a time vector 
time_array = np.arange(0, tduration, 1./4096) 

# Time Domain Newtonian Chirp Signal
hoft, index =td_newtonian_chirp(m1= 20, m2=10, fnot=30, phi_not=0, distance=100, time_range=time_array)
# Out:
# ------------------------------------------------------------------
#  Chirp Mass (Solar Mass sec)             : 4.287888986796965e-05
#  Coalescence time (sec)                  : 2.0211620924221205
#  Frequency evolution - First data point  : 30.0
#  Amplitude - First data point            : 4.22782292190318e-22
#  Phase - First data point                : -609.5681262016794
#  TD Newtonian chirp - First data point   : 4.2070580758354534e-22
# ------------------------------------------------------------------

# %% [markdown]
# <u> <font color="green"> Check Points of your results </font></u>
#
# |  |  |
# | --- | --- |
# | Chirp Mass (Solar Mass sec)             | 5.9929862125114186e-05 |
# | Coalescence time (sec)                  | 1.1568265168522474 |
# | Frequency evolution - First data point  | 30.0 |
# | Amplitude - First data point            | 7.386687025877914e-22 |
# | Phase - First data point                | -348.8906579348046 |
# | TD Newtonian chirp - First data point   | -7.275311050366615e-22 |

# %% [markdown]
# <u> <font color="green"> Write time domain Newtonian Chirp Signal data and plot the signal </font></u>

# %%
# Write data into the file
writeData = open("nchirp.dat","w")
for i in range (len(hoft)):
    writeData.write(str(time_array[i])+','+str(hoft[i])+'\n')

writeData.close()

# Plot the results
plt.plot(time_array[index], hoft[index])
plt.title(" Time Domain Newtonian Chirp Signal")
plt.xlabel(" Time (seconds) ")
plt.show()

# %% [markdown]
# <u> <font color="magent"> Time Domain Newotinian Chirp Signal </font></u>
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <h3><center><u> <font color="brown"> Coding help in Python 3 </font> </u></center><h3>
#
# * Data Types Examples
#   * integers:  -10, 10
#   * float:  -10. , 10.0, 23.5
#
# * Division operators
#   * '/'
#          Ex: 6/4 = 1.5
#   * '//'
#          Ex: 6//4 = 1  (Quotient)
#   * '%'
#          Ex: 6%4 = 2 (Reminder)
#
# * Multiplication operator
#   * '*'
#          Ex: 6  * 4 = 24  (Integer)
#          Ex: 6. * 4 = 24.0 (Float)
# * Power operator
#   * '**'
#          Ex: 6 ** 4 = 1296 (Integer)
#          Ex: 6 ** 4. = 1296.0 (Float)
#
# * π = PI
#
#   np.pi
#
# * cos = COS
#
#   np.cos()

# %% [markdown]
# <u> <font color="green"> References </font></u>
